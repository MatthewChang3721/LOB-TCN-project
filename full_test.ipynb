# %%
# %run full-test.py
# Out:
# Configuration loaded: TPU_Phase2_Stress_Test
# Testing Batch sizes: [256, 1024, 4096, 16384, 65536]
# E0000 00:00:1776894915.915968    7068 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# --- Testing Batch Size: 256. ---
#  Step 0000 | Loss: 8.8108 | Acc: 0.1289
#  Step 0050 | Loss: 0.9821 | Acc: 0.4805
#  Step 0100 | Loss: 0.9271 | Acc: 0.5664
#  Step 0150 | Loss: 0.9545 | Acc: 0.5469
#  Step 0200 | Loss: 0.9393 | Acc: 0.5234
#  Step 0250 | Loss: 0.9293 | Acc: 0.5742
#  Step 0300 | Loss: 0.9089 | Acc: 0.5586
#  Step 0350 | Loss: 0.9296 | Acc: 0.5391
#  Step 0400 | Loss: 0.9548 | Acc: 0.5430
#  Step 0450 | Loss: 0.9866 | Acc: 0.5039
# ✅ Done 500 Steps! Total time: 8.48s
# 🚀 XLA Time + first step(approximate): 3.05452823638916.
# 🚀 Second step: 2.7582859992980957.
# ⚡ Second per step: 0.00535382s
# 📊 Data I/O: 47816.0 samples/sec
# --- Testing Batch Size: 1024. ---
#  Step 0000 | Loss: 8.1112 | Acc: 0.1514
# ...
